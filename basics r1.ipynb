# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashidwivedi438/yashis-demo/blob/main/basics%20r1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=10
y=20
sum=x+y
print(sum)
# Out:
# [1] 30

# %%
n=5
fact=1
for(i in 1:n){
  fact=fact*i
}
print(fact)
# Out:
# [1] 120

# %%
name="yashi"
age=20
marks=90
print(name)
print(age)
print(marks)
# Out:
# [1] "yashi"
# [1] 20
# [1] 90

# %%
#basic addition subtraction of r
a=10
b=20
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# [1] 30
# [1] -10
# [1] 200
# [1] 0.5

# %%
#finding square
n=5
square=n*n
print(square)
# Out:
# [1] 25

# %%
#finding square of numbers given by user
n=as.numeric(readline("enter a number"))
print(n)
print(n*n)
# Out:
# enter a number4
# [1] 4
# [1] 16

# %%
#finding cuberoot
n=4
print(n*n*n)
# Out:
# [1] 64

# %%
#finding cuberoot of a number given by a user
n=as.numeric(readline("enter ur numbr"))
print(n)
print(n*n*n)
# Out:
# enter ur numbr289
# [1] 289
# [1] 24137569
